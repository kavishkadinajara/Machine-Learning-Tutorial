# %% [markdown]
# ![Screenshot 2024-06-24 163822.png](<attachment:Screenshot 2024-06-24 163822.png>)

# %%
import pandas as pd

data = pd.read_csv('abc.csv')
data
# Out:
#    age  salary  success
# 0   26   50000        1
# 1   29   70000        1
# 2   34   55000        0
# 3   31   41000        0

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaled_data = pd.DataFrame(scaler.fit_transform(data))
scaled_data
# Out:
#        0         1    2
# 0  0.000  0.310345  1.0
# 1  0.375  1.000000  1.0
# 2  1.000  0.482759  0.0
# 3  0.625  0.000000  0.0
