# %% [markdown]
# ![Screenshot 2024-06-24 163935.png](<attachment:Screenshot 2024-06-24 163935.png>)

# %%
import pandas as pd

data  = pd.read_csv('abc.csv')
data
# Out:
#    age  salary  success
# 0   26   50000        1
# 1   29   70000        1
# 2   34   55000        0
# 3   31   41000        0

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = pd.DataFrame(scaler.fit_transform(data))
scaled_data
# Out:
#           0         1    2
# 0 -1.371989 -0.380521  1.0
# 1 -0.342997  1.522085  1.0
# 2  1.371989  0.095130 -1.0
# 3  0.342997 -1.236694 -1.0
