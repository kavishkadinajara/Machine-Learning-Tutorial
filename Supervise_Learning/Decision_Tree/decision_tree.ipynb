# %% [markdown]
# ![Screenshot 2024-06-24 195517.png](<attachment:Screenshot 2024-06-24 195517.png>)
# ![Screenshot 2024-06-24 200030.png](<attachment:Screenshot 2024-06-24 200030.png>)
# ![Screenshot 2024-06-24 200115.png](<attachment:Screenshot 2024-06-24 200115.png>)
# ![Screenshot 2024-06-24 205008.png](<attachment:Screenshot 2024-06-24 205008.png>)

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('kyphosis.csv')
data.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
data.shape
# Out:
# (81, 4)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
x = data.drop('Kyphosis', axis=1)
x.head()
# Out:
#    Age  Number  Start
# 0   71       3      5
# 1  158       3     14
# 2  128       4      5
# 3    2       5      1
# 4    1       4     15

# %%
y = data['Kyphosis']
y.head()
# Out:
# 0     absent
# 1     absent
# 2    present
# 3     absent
# 4     absent
# Name: Kyphosis, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %%
x_train.shape
# Out:
# (60, 3)

# %% [markdown]
# ## USE DECISION TREE

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predict = model.predict(x_test)
predict
# Out:
# array(['absent', 'present', 'absent', 'absent', 'absent', 'absent',
#        'absent', 'absent', 'absent', 'absent', 'absent', 'absent',
#        'present', 'absent', 'absent', 'absent', 'absent', 'absent',
#        'absent', 'absent', 'absent'], dtype=object)

# %%
y_test
# Out:
# 30     absent
# 42     absent
# 29     absent
# 66     absent
# 34     absent
# 33     absent
# 45    present
# 74     absent
# 15     absent
# 24    present
# 72     absent
# 69     absent
# 79    present
# 19     absent
# 25     absent
# 47     absent
# 56     absent
# 80     absent
# 7      absent
# 20     absent
# 8      absent
# Name: Kyphosis, dtype: object

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, predict)
accuracy
# Out:
# 0.8571428571428571

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, predict)
cm
# Out:
# array([[17,  1],
#        [ 2,  1]], dtype=int64)
