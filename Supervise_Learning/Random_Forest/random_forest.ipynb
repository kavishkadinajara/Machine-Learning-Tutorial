# %% [markdown]
# ![Screenshot 2024-06-26 111617.png](<attachment:Screenshot 2024-06-26 111617.png>)
# ![Screenshot 2024-06-26 111655.png](<attachment:Screenshot 2024-06-26 111655.png>)
# ![Screenshot 2024-06-26 111855.png](<attachment:Screenshot 2024-06-26 111855.png>)

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('kyphosis.csv')
data.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
data.shape
# Out:
# (81, 4)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
x = data.drop('Kyphosis', axis=1)
x.head()
# Out:
#    Age  Number  Start
# 0   71       3      5
# 1  158       3     14
# 2  128       4      5
# 3    2       5      1
# 4    1       4     15

# %%
y = data['Kyphosis']
y.head()
# Out:
# 0     absent
# 1     absent
# 2    present
# 3     absent
# 4     absent
# Name: Kyphosis, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x_train.shape
# Out:
# (64, 3)

# %%
y_train.shape
# Out:
# (64,)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=50)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=50)

# %%
predict = model.predict(x_test)

# %%
y_test
# Out:
# 7      absent
# 78     absent
# 70     absent
# 41     absent
# 4      absent
# 26     absent
# 18     absent
# 65     absent
# 8      absent
# 71     absent
# 72     absent
# 9     present
# 15     absent
# 31     absent
# 38     absent
# 79    present
# 53     absent
# Name: Kyphosis, dtype: object

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, predict)
accuracy
# Out:
# 0.8823529411764706
